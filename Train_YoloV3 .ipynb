# %%
# !nvidia-smi
# Out:
# Tue Nov 16 13:55:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
#  BudowaMaks	    eBookpoint	'My Drive'   yolo_custom_model_Training
# 'car model'	    Gsgegeys	 petuniowa   yolov3
# 'Colab Notebooks'  'Łajka vid'	 yolo	    'zadania II_MJackowski'

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15363, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 15363 (delta 0), reused 3 (delta 0), pack-reused 15358
# Receiving objects: 100% (15363/15363), 13.98 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (10329/10329), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 21000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=7@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=7@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=7@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=36@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=36@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=36@' cfg/yolov3_training.cfg

# %%
# !mkdir "/mydrive/yolov3"
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov3’: File exists

# %%
# !echo "car\nmotor\nvan\ntruck\nbike\nperson\nbus" > data/obj.names
# !echo -e 'classes= 7\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data
# !mkdir data/obj

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-11-16 15:41:21--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  23.1MB/s    in 7.4s
#
# 2021-11-16 15:41:29 (20.9 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !unzip /mydrive/yolov3/images.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3/images.zip
#   inflating: data/obj/9_1.jpg
#   inflating: data/obj/9_1.txt
#   inflating: data/obj/9_2.jpg
#   inflating: data/obj/9_2.txt
#   inflating: data/obj/9_3.jpg
#   inflating: data/obj/9_3.txt
#   inflating: data/obj/9_4.jpg
#   inflating: data/obj/9_4.txt
#   inflating: data/obj/9_5.jpg
#   inflating: data/obj/9_5.txt
#   inflating: data/obj/9_6.jpg
#   inflating: data/obj/9_6.txt
#   inflating: data/obj/9_7.jpg
#   inflating: data/obj/9_7.txt
#   inflating: data/obj/9_8.txt
#   inflating: data/obj/9_8.webp
#   inflating: data/obj/9_9.jpg
#   inflating: data/obj/9_9.txt
#   inflating: data/obj/9_10.jpg
#   inflating: data/obj/9_10.txt
#   inflating: data/obj/9_11.jpg
#   inflating: data/obj/9_11.txt
#   inflating: data/obj/9_12.jpg
#   inflating: data/obj/9_12.txt
#   inflating: data/obj/9_13.crdownload
#   inflating: data/obj/9_14.jpg
#   inflating: data/obj/9_14.txt
#   inflating: data/obj/9_15.txt
#   inflating: data/obj/9_15.webp
# ...

# %%
import glob
import os
import re

txt_file_paths = glob.glob(r"data/obj/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2 0.251953 0.477083 0.124219 0.193056
#
# ['2', '0.251953', '0.477083', '0.124219', '0.193056']
# 560 data/obj/vid5_0.txt
# 0 0.251953 0.477083 0.124219 0.193056
# 2 0.118750 0.501389 0.101562 0.186111
#
# ['2', '0.118750', '0.501389', '0.101562', '0.186111']
# 560 data/obj/vid5_0.txt
# 0 0.118750 0.501389 0.101562 0.186111
# 2 0.117969 0.318750 0.057813 0.095833
#
# ['2', '0.117969', '0.318750', '0.057813', '0.095833']
# 560 data/obj/vid5_0.txt
# 0 0.117969 0.318750 0.057813 0.095833
# 2 0.678125 0.465972 0.146875 0.112500
#
# ['2', '0.678125', '0.465972', '0.146875', '0.112500']
# 560 data/obj/vid5_0.txt
# 0 0.678125 0.465972 0.146875 0.112500
# 2 0.825391 0.551389 0.167969 0.186111
#
# ['2', '0.825391', '0.551389', '0.167969', '0.186111']
# 560 data/obj/vid5_0.txt
# 0 0.825391 0.551389 0.167969 0.186111
# 2 0.503906 0.346528 0.078125 0.115278
#
# ['2', '0.503906', '0.346528', '0.078125', '0.115278']
# 561 data/obj/vid6_208.txt
# ...

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
print(images_list)
# Out:
# ['data/obj/a9_28.jpg', 'data/obj/vid8_3.jpg', 'data/obj/a9_39.jpg', 'data/obj/vid6_25.jpg', 'data/obj/vid6_105.jpg', 'data/obj/vid6_533.jpg', 'data/obj/vid6_624.jpg', 'data/obj/9_10.jpg', 'data/obj/vid2_26.jpg', 'data/obj/vid6_138.jpg', 'data/obj/vid2_8.jpg', 'data/obj/vid6_44.jpg', 'data/obj/vid6_107.jpg', 'data/obj/vid6_400.jpg', 'data/obj/vid6_169.jpg', 'data/obj/vid1_11.jpg', 'data/obj/vid6_393.jpg', 'data/obj/vid6_556.jpg', 'data/obj/vid6_514.jpg', 'data/obj/vid8_1.jpg', 'data/obj/vid1_71.jpg', 'data/obj/vid6_494.jpg', 'data/obj/vid5_3.jpg', 'data/obj/vid2_19.jpg', 'data/obj/vid6_571.jpg', 'data/obj/vid6_564.jpg', 'data/obj/vid6_408.jpg', 'data/obj/a9_19.jpg', 'data/obj/vid7_479.jpg', 'data/obj/vid6_398.jpg', 'data/obj/vid6_491.jpg', 'data/obj/a9_63.jpg', 'data/obj/a9_2.jpg', 'data/obj/vid6_414.jpg', 'data/obj/vid5_25.jpg', 'data/obj/vid6_390.jpg', 'data/obj/vid1_20.jpg', 'data/obj/vid6_55.jpg', 'data/obj/vid6_35.jpg', 'data/obj/vid4_11.jpg', 'data/obj/9_20.jpg', 'data/obj/vid1_
# ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %%
# Start the trainin
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  1402: 0.893369, 0.967658 avg loss, 0.001000 rate, 2.407916 seconds, 89728 images, 18.245704 hours left
# Loaded: 0.000042 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.788117), count: 1, class_loss = 0.000141, iou_loss = 0.027473, total_loss = 0.027614
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.791837), count: 25, class_loss = 1.080048, iou_loss = 0.838371, total_loss = 1.918419
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.747871), count: 7, class_loss = 1.343842, iou_loss = 0.253215, total_loss = 1.597057
#  total_bbox = 480966, rewritten_bbox = 0.095849 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.902423), count: 1, class_loss = 0.185951, iou_loss = 0.019215, total_loss = 0.205166
# ...
